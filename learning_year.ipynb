# %%
# D:\Toppan\jupyter\per machine

import pandas as pd
import os
import numpy as np
from datetime import timedelta
import time
import glob

from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

in_dir = 'D:\\Toppan\\2017-11-20 全データ\\処理済(総量)\\vectorized_keikaku_shibata'
files = [f for f in os.listdir(in_dir)]

voc_dir_base = 'D:\\Toppan\\2017-11-20 全データ\\データ\\'


base_out_dir = 'D:\\Toppan\\2017-11-20 全データ\\解析結果(総量)\\年間モデル\\追加学習なし'

# train and test data
energies = ['蒸気', '冷水', '電力']
month = [ '16年11月', '16年12月', '17年1月', '17年2月', '17年3月', '17年4月',
         '17年5月', '17年6月', '17年7月', '17年8月', '17年9月', '17年10月', 
         '17年11月', '17年12月', '18年1月', '18年2月']

month_file = [  '201611010800.xlsx', '201612010800.xlsx', 
                '201701010800.xlsx', '201702010800.xlsx', '201703010800.xlsx',
                '201704010800.xlsx', '201705010800.xlsx', '201706010800.xlsx',
                '201707010800.xlsx', '201708010800.xlsx', '201709010800.xlsx',
                '201710010800.xlsx',  '201711010800.xlsx', '201712010800.xlsx', 
              '201801010800.xlsx', '201802010800.xlsx', ]

# %%
def read_df(file, month, sheet_name):
    
    # data
    df = pd.read_excel(os.path.join(in_dir, file), sheet_name=sheet_name)
    
    # April special case
    if month == '17年4月':
        df = df.iloc[:358]
    
    # voc
    voc_dir = os.path.join(voc_dir_base, month, 'VOC再利用追加')
    voc_f = glob.glob(voc_dir + '/*.csv')[0]
    df_voc = pd.read_csv(voc_f, index_col=0, 
                         encoding='shift-jis', 
                         engine='python', 
                         parse_dates=True).fillna(0)
    
    df.columns = [
        '総稼動時間-3', '計画投入数(Ｒ)-3', '外気温度-3', '外気湿度-3', '計画色数-3', '段取-3', 
        '計画停止-3', '計画開始完了数-3', sheet_name + '-3',
        
        '総稼動時間-2', '計画投入数(Ｒ)-2', '外気温度-2', '外気湿度-2', '計画色数-2', '段取-2', 
        '計画停止-2', '計画開始完了数-2', sheet_name + '-2',
        
        '総稼動時間-1', '計画投入数(Ｒ)-1', '外気温度-1', '外気湿度-1', '計画色数-1', '段取-1', 
        '計画停止-1', '計画開始完了数-1', sheet_name + '-1',
        
        'target']
    
    # add voc to data
    df['VOC燃料生成量-3'] = pd.Series(data=df_voc['VOC燃料生成量'].iloc[:-2].values, index=df.index)
    df['VOC燃料生成量-2'] = pd.Series(data=df_voc['VOC燃料生成量'].iloc[1:-1].values, index=df.index)
    df['VOC燃料生成量-1'] = pd.Series(data=df_voc['VOC燃料生成量'].iloc[2:].values, index=df.index)
    
    df['VOC再利用生成量-3'] = pd.Series(data=df_voc['VOC再利用生成量'].iloc[:-2].values, index=df.index)
    df['VOC再利用生成量-2'] = pd.Series(data=df_voc['VOC再利用生成量'].iloc[1:-1].values, index=df.index)
    df['VOC再利用生成量-1'] = pd.Series(data=df_voc['VOC再利用生成量'].iloc[2:].values, index=df.index)
    
    return df

# %%
def read_df__(file, month, sheet_name):
    
    # data
    df = pd.read_excel(os.path.join(in_dir, file), sheet_name=sheet_name)
    
    df.columns = [
        '総稼動時間-3', '計画投入数(Ｒ)-3', '外気温度-3', '外気湿度-3', '計画色数-3', '段取-3', 
        '計画停止-3', '計画開始完了数-3', sheet_name + '-3',
        
        '総稼動時間-2', '計画投入数(Ｒ)-2', '外気温度-2', '外気湿度-2', '計画色数-2', '段取-2', 
        '計画停止-2', '計画開始完了数-2', sheet_name + '-2',
        
        '総稼動時間-1', '計画投入数(Ｒ)-1', '外気温度-1', '外気湿度-1', '計画色数-1', '段取-1', 
        '計画停止-1', '計画開始完了数-1', sheet_name + '-1',
        
        'target']
    
    return df

# %%
holiday_path = 'D:\\Toppan\\2017-11-20 全データ\\データ\\切り離し全休日\\全休日.xlsx'

def mask_out(X, y, month):
    
    try:
        df_filter = pd.read_excel(holiday_path, sheet_name=month, index_col=0).iloc[2:]
        seisan = True if '生産\n有無' in df_filter else False
        
    except Exception as e:
        print(e, month)
        return X, y
    
    def isBusy(idx):
        row = df_filter.loc[idx]

        if row.loc['切離\n有無'] == '切離' or row.loc['全休\n判定'] == '全休' \
            or row.loc['異常判定'] == '※異常稼動' or row.loc['異常判定'] == '※データ異常' \
            or (seisan and row.loc['生産\n有無'] == '無'):
            return False
        else:
            return True

    x_busy_idx = []
    y_busy_idx = []
    for x_idx, y_idx in zip (X.index, y.index):
        if isBusy(x_idx) and isBusy(y_idx):
            x_busy_idx.append(x_idx)
            y_busy_idx.append(y_idx)

    return X.loc[x_busy_idx], y.loc[y_busy_idx]

# %%
def save_fig(g, g_name):

    # seaborn graph
    g.set_xlabel("Relative importance",fontsize=12)
    g.set_ylabel("Features",fontsize=12)
    g.tick_params(labelsize=9)
    g.set_title(g_name + " feature importance")
    g.get_figure().savefig(os.path.join(out_dir, g_name + '.png'))
    

def get_importance_figure(model, name, features):
    
    indices = np.argsort(model.feature_importances_)[::-1]
    
    # save csv
    s = pd.Series(data=model.feature_importances_[indices], 
              index=features[indices])
    s.to_csv(os.path.join(out_dir, name + '_寄与度.csv'), encoding='shift-jis')
    
    return

    # all features
    g = sns.barplot(y=features[indices], 
                    x=model.feature_importances_[indices], 
                    orient='h')
    save_fig(g, name + '_all_features')
    
def get_importance_figure_2(model, name, features):
    
    indices = np.argsort(model.feature_importances_)[::-1]
    
    # features without vapors
    feats, feat_importances = [], []
    for i in indices:
        if name not in features[i]:
            feats.append(features[i])
            feat_importances.append(model.feature_importances_[i])
    
    gg = sns.barplot(y=feats, 
                    x=feat_importances, 
                    orient='h')
    save_fig(g, name + '_without_vapors')

# %%
def split_day_night(acc_abs):
    acc_abs_days, acc_abs_nights = [], []
    for i, acc in acc_abs.iteritems():
        if 7 < i.hour < 22:
            acc_abs_days.append(acc)
        else:
            acc_abs_nights.append(acc)

    return acc_abs_days, acc_abs_nights

def get_output(res, output, sname, month):
    res = res[res['target'] != 0]
    
    if len(res) == 0:
        return None
    
    y_pred, y_true = res['preds'], res['target']
    '''calculate abs accuracy'''
    acc_abs = abs(y_pred - y_true) / y_true
    '''aplit days and nights'''
    acc_abs_days, acc_abs_nights = split_day_night(acc_abs)
    len_days, len_nights = len(acc_abs_days), len(acc_abs_nights)

    sname2acc = {'蒸気': [0.2, 0.15], '電力': [0.09, 0.15], '冷水': [0.15, 0.1]}

    '''acc stats'''
    len_acc_days = len(list(filter(lambda x: x <= sname2acc[sname][0], acc_abs_days)))
    len_acc_nights = len(list(filter(lambda x: x <= sname2acc[sname][0], acc_abs_nights)))
    acc_stats_days = len_acc_days / len_days
    acc_stats_nights = len_acc_nights / len_nights

    output['設備名'].append(month + '_' + sname)
    output['平日昼・総'].append(len_days)
    output['平日夜・総'].append(len_nights)
    output['平日昼・基準内'].append(len_acc_days)
    output['平日夜・基準内'].append(len_acc_nights)
    output['平日昼基準率'].append(acc_stats_days)
    output['平日夜基準率'].append(acc_stats_nights)

    return output

# %%
def remove_noise(X, Y, energy_name):
    
    if energy_name != '電力':
        return
    
    for idx, row in X.iterrows():
        
        energy_vals = [row[energy_name + '-1'], 
         row[energy_name + '-2'], 
         row[energy_name + '-3']]
        
        if any([x > 10000 for x in energy_vals]):
            
            X.drop([idx], inplace=True)
            Y.drop([idx + timedelta(hours=1)], inplace=True)
    
    for idx, item in Y.iteritems():
        if item > 10000:
            X.drop([idx - timedelta(hours=1)], inplace=True)
            Y.drop([idx], inplace=True)
            
    
    return X, Y

# %%
df = read_df__('201711010800.xlsx', '17年11月', '電力')

X_test, Y_test = mask_out(df.drop(columns=['target']).iloc[:-1], 
                          df['target'].iloc[1:], '17年11月')

print(X_test.shape, Y_test.shape)

X_test, Y_test = remove_noise(X_test, Y_test, '電力')

print(X_test.shape, Y_test.shape)



'''
17年5月 2017-05-05 18:00:00 655512
17年5月 2017-05-10 02:00:00 90003955

17年11月 2017-11-28 07:00:00 20006085
'''
#Y_test.index[-100:]
# Out:
# (656, 27) (656,)
# (652, 27) (652,)
# '\n17年5月 2017-05-05 18:00:00 655512\n17年5月 2017-05-10 02:00:00 90003955\n\n17年11月 2017-11-28 07:00:00 20006085\n'

# %% [markdown]
# ### 年間データを Leave-One-Out で学習・予測

# %%
total_acc = []

energy2name = {'蒸気': 'vapor', '冷水': 'cold water', '電力': 'electric power'}

for m, f in zip(month, month_file):

    #if m  in ['17年7月', '17年8月', '17年9月', '17年10月']: continue
    
    print(m)
    # create output dir
    out_dir = os.path.join(base_out_dir, m)
    if not os.path.exists(out_dir):
        os.makedirs(out_dir)

    # set train and test files
    test_month, test_month_file = m, f
    train_month, train_month_file = [x for x in month if x != m], \
                                            [x for x in month_file if x != f]
    
    for energy in energies:
        
        # learning files
        X_learn, Y_learn = [], []
        for f, m in zip(train_month_file, train_month):
            try:
                
                df = read_df__(f, m, energy)
                
            except Exception:
                print(f, m, energy)
            
            x, y = mask_out(df.drop(columns=['target']).iloc[:-1], 
                            df['target'].iloc[1:], m)

            X_learn.append(x)
            Y_learn.append(y)

        X_learn, Y_learn = pd.concat(X_learn), pd.concat(Y_learn)

        # test file
        df = read_df__(test_month_file, test_month, energy)
        X_test, Y_test = mask_out(df.drop(columns=['target']).iloc[:-1], 
                                  df['target'].iloc[1:], test_month)
        
        # remove noise
        if energy == '電力':
            remove_noise(X_learn, Y_learn, '電力')
            remove_noise(X_test, Y_test, '電力')
        
        # model
        model = ExtraTreesRegressor(n_estimators=700, 
                                      n_jobs=-1, 
                                      max_depth=11, 
                                      max_features='auto', 
                                      criterion='mae', 
                                      random_state=700, 
                                      warm_start=True)
        
        # learn 1 hour later target
        start = time.time()
        model.fit(X_learn, Y_learn)
        elapsed_time = time.time() - start

        print(test_month, energy, 'elapsed time: ', elapsed_time, 's')

        # feature importance
        get_importance_figure(model, energy2name[energy], X_test.columns)
        
        # test with online learning
        preds = []
        for idx, row in X_test.iterrows():

            # predict
            preds.append(model.predict(row.values.reshape(1, -1))[0])

            # online learning
            '''
            model.n_estimators += 50

            X_learn = X_learn.append(row)
            Y_learn = Y_learn.append(pd.Series(data=Y_test.loc[idx + timedelta(hours=1)], 
                      index=[idx + timedelta(hours=1)]))

            model.fit(X_learn, Y_learn)
            '''

        # save preds and test
        preds = pd.Series(data=preds, index=Y_test.index, name='preds')
        result = pd.concat([preds, Y_test], axis=1)
        result.to_csv(os.path.join(out_dir, energy + '.csv'), encoding='shift-jis')

        # accuracy
        output = {'設備名': [], 
                  '平日昼・総': [], '平日夜・総': [], 
                  '平日昼・基準内': [], '平日夜・基準内': [], 
                  '平日昼基準率': [], '平日夜基準率': []}
        
        output = get_output(result, output, energy, test_month)
        
        print(test_month, energy, output)

        # save accuracy
        accs = pd.DataFrame(output)
        accs.to_csv(os.path.join(out_dir, energy + '_acc.csv'), index=False, encoding='shift-jis')
        
        total_acc.append(accs)
        
total_acc = pd.concat(total_acc)
total_acc.to_csv(os.path.join(base_out_dir, 'total_acc.csv'), index=False, encoding='shift-jis')
# Out:
# 16年11月
# 16年11月 蒸気 elapsed time:  241.57633662223816 s
# 16年11月 蒸気 {'設備名': ['16年11月_蒸気'], '平日昼・総': [352], '平日夜・総': [251], '平日昼・基準内': [304], '平日夜・基準内': [233], '平日昼基準率': [0.8636363636363636], '平日夜基準率': [0.9282868525896414]}
# 16年11月 冷水 elapsed time:  280.9427468776703 s
# 16年11月 冷水 {'設備名': ['16年11月_冷水'], '平日昼・総': [352], '平日夜・総': [251], '平日昼・基準内': [328], '平日夜・基準内': [216], '平日昼基準率': [0.9318181818181818], '平日夜基準率': [0.8605577689243028]}
# 16年11月 電力 elapsed time:  363.74807119369507 s
# 16年11月 電力 {'設備名': ['16年11月_電力'], '平日昼・総': [352], '平日夜・総': [251], '平日昼・基準内': [338], '平日夜・基準内': [246], '平日昼基準率': [0.9602272727272727], '平日夜基準率': [0.9800796812749004]}
# 16年12月
# 16年12月 蒸気 elapsed time:  245.44087481498718 s
# 16年12月 蒸気 {'設備名': ['16年12月_蒸気'], '平日昼・総': [152], '平日夜・総': [243], '平日昼・基準内': [136], '平日夜・基準内': [232], '平日昼基準率': [0.8947368421052632], '平日夜基準率': [0.9547325102880658]}
# 16年12月 冷水 elapsed time:  288.80213499069214 s
# 16年12月 冷水 {'設備名': ['16年12月_冷水'], '平日昼・総': [149], '平日夜・総': [243], '平日昼・基準内': [144], '平日夜・基準内': [242], '平日昼基準率': [0.9664429530201343], '平日夜基準率': [0.9958847736625515]}
# 16年12月 電力 elapsed time:  372.7140688896179 s
# 16年12月 電力 {'設備名': ['16年12月_電力'], '平日昼・総': [151], '平日夜・総': [243], '平日昼・基準内': [143], '平日夜・基準内': [238], '平日昼基準率': [0.9470198675496688], '平日夜基準率': [0.9794238683127572]}
# 17年1月
# 17年1月 蒸気 elapsed time:  256.3638434410095 s
# 17年1月 蒸気 {'設備名': ['17年1月_蒸気'], '平日昼・総': [93], '平日夜・総': [222], '平日昼・基準内': [86], '平日夜・基準内': [210], '平日昼基準率': [0.9247311827956989], '平日夜基準率': [0.9459459459459459]}
# 17年1月 冷水 elapsed time:  297.95358300209045 s
# 17年1月 冷水 {'設備名': ['17年1月_冷水'], '平日昼・総': [93], '平日夜・総': [222], '平日昼・基準内': [91], '平日夜・基準内': [215], '平日昼基準率': [0.978494623655914], '平日夜基準率': [0.9684684684684685]}
# 17年1月 電力 elapsed time:  377.6617262363434 s
# 17年1月 電力 {'設備名': ['17年1月_電力'], '平日昼・総': [93], '平日夜・総': [222], '平日昼・基準内': [91], '平日夜・基準内': [215], '平日昼基準率': [0.978494623655914], '平日夜基準率': [0.9684684684684685]}
# 17年2月
# 17年2月 蒸気 elapsed time:  231.70651507377625 s
# 17年2月 蒸気 {'設備名': ['17年2月_蒸気'], '平日昼・総': [343], '平日夜・総': [235], '平日昼・基準内': [321], '平日夜・基準内': [226], '平日昼基準率': [0.9358600583090378], '平日夜基準率': [0.9617021276595744]}
# 17年2月 冷水 elapsed time:  284.4932806491852 s
# 17年2月 冷水 {'設備名': ['17年2月_冷水'], '平日昼・総': [343], '平日夜・総': [235], '平日昼・基準内': [334], '平日夜・基準内': [227], '平日昼基準率': [0.9737609329446064], '平日夜基準率': [0.9659574468085106]}
# 17年2月 電力 elapsed time:  352.80603790283203 s
# 17年2月 電力 {'設備名': ['17年2月_電力'], '平日昼・総': [343], '平日夜・総': [235], '平日昼・基準内': [338], '平日夜・基準内': [231], '平日昼基準率': [0.9854227405247813], '平日夜基準率': [0.9829787234042553]}
# 17年3月
# 17年3月 蒸気 elapsed time:  235.1716113090515 s
# 17年3月 蒸気 {'設備名': ['17年3月_蒸気'], '平日昼・総': [370], '平日夜・総': [286], '平日昼・基準内': [338], '平日夜・基準内': [270], '平日昼基準率': [0.9135135135135135], '平日夜基準率': [0.9440559440559441]}
# 17年3月 冷水 elapsed time:  275.1286416053772 s
# 17年3月 冷水 {'設備名': ['17年3月_冷水'], '平日昼・総': [370], '平日夜・総': [286], '平日昼・基準内': [363], '平日夜・基準内': [282], '平日昼基準率': [0.981081081081081], '平日夜基準率': [0.986013986013986]}
# 17年3月 電力 elapsed time:  350.74431133270264 s
# 17年3月 電力 {'設備名': ['17年3月_電力'], '平日昼・総': [370], '平日夜・総': [286], '平日昼・基準内': [362], '平日夜・基準内': [282], '平日昼基準率': [0.9783783783783784], '平日夜基準率': [0.986013986013986]}
# 17年4月
# 17年4月 蒸気 elapsed time:  236.15084028244019 s
# 17年4月 蒸気 {'設備名': ['17年4月_蒸気'], '平日昼・総': [394], '平日夜・総': [283], '平日昼・基準内': [334], '平日夜・基準内': [250], '平日昼基準率': [0.8477157360406091], '平日夜基準率': [0.8833922261484098]}
# 17年4月 冷水 elapsed time:  280.9237771034241 s
# 17年4月 冷水 {'設備名': ['17年4月_冷水'], '平日昼・総': [394], '平日夜・総': [283], '平日昼・基準内': [375], '平日夜・基準内': [264], '平日昼基準率': [0.9517766497461929], '平日夜基準率': [0.9328621908127208]}
# 17年4月 電力 elapsed time:  356.39514327049255 s
# 17年4月 電力 {'設備名': ['17年4月_電力'], '平日昼・総': [394], '平日夜・総': [283], '平日昼・基準内': [389], '平日夜・基準内': [282], '平日昼基準率': [0.9873096446700508], '平日夜基準率': [0.9964664310954063]}
# 17年5月
# 17年5月 蒸気 elapsed time:  247.84474658966064 s
# 17年5月 蒸気 {'設備名': ['17年5月_蒸気'], '平日昼・総': [364], '平日夜・総': [254], '平日昼・基準内': [312], '平日夜・基準内': [225], '平日昼基準率': [0.8571428571428571], '平日夜基準率': [0.8858267716535433]}
# 17年5月 冷水 elapsed time:  312.49628233909607 s
# 17年5月 冷水 {'設備名': ['17年5月_冷水'], '平日昼・総': [360], '平日夜・総': [254], '平日昼・基準内': [352], '平日夜・基準内': [248], '平日昼基準率': [0.9777777777777777], '平日夜基準率': [0.9763779527559056]}
# 17年5月 電力 elapsed time:  364.64969539642334 s
# 17年5月 電力 {'設備名': ['17年5月_電力'], '平日昼・総': [363], '平日夜・総': [253], '平日昼・基準内': [356], '平日夜・基準内': [247], '平日昼基準率': [0.9807162534435262], '平日夜基準率': [0.9762845849802372]}
# 17年6月
# 17年6月 蒸気 elapsed time:  242.95407104492188 s
# 17年6月 蒸気 {'設備名': ['17年6月_蒸気'], '平日昼・総': [384], '平日夜・総': [273], '平日昼・基準内': [332], '平日夜・基準内': [244], '平日昼基準率': [0.8645833333333334], '平日夜基準率': [0.8937728937728938]}
# 17年6月 冷水 elapsed time:  300.5799169540405 s
# 17年6月 冷水 {'設備名': ['17年6月_冷水'], '平日昼・総': [384], '平日夜・総': [273], '平日昼・基準内': [377], '平日夜・基準内': [270], '平日昼基準率': [0.9817708333333334], '平日夜基準率': [0.989010989010989]}
# 17年6月 電力 elapsed time:  365.06623673439026 s
# 17年6月 電力 {'設備名': ['17年6月_電力'], '平日昼・総': [384], '平日夜・総': [273], '平日昼・基準内': [379], '平日夜・基準内': [271], '平日昼基準率': [0.9869791666666666], '平日夜基準率': [0.9926739926739927]}
# 17年7月
# 17年7月 蒸気 elapsed time:  243.69241094589233 s
# 17年7月 蒸気 {'設備名': ['17年7月_蒸気'], '平日昼・総': [376], '平日夜・総': [288], '平日昼・基準内': [313], '平日夜・基準内': [248], '平日昼基準率': [0.8324468085106383], '平日夜基準率': [0.8611111111111112]}
# 17年7月 冷水 elapsed time:  292.93931341171265 s
# 17年7月 冷水 {'設備名': ['17年7月_冷水'], '平日昼・総': [376], '平日夜・総': [288], '平日昼・基準内': [376], '平日夜・基準内': [288], '平日昼基準率': [1.0], '平日夜基準率': [1.0]}
# 17年7月 電力 elapsed time:  369.30691933631897 s
# 17年7月 電力 {'設備名': ['17年7月_電力'], '平日昼・総': [376], '平日夜・総': [288], '平日昼・基準内': [374], '平日夜・基準内': [279], '平日昼基準率': [0.9946808510638298], '平日夜基準率': [0.96875]}
# 17年8月
# 17年8月 蒸気 elapsed time:  252.47751379013062 s
# 17年8月 蒸気 {'設備名': ['17年8月_蒸気'], '平日昼・総': [290], '平日夜・総': [203], '平日昼・基準内': [246], '平日夜・基準内': [177], '平日昼基準率': [0.8482758620689655], '平日夜基準率': [0.8719211822660099]}
# 17年8月 冷水 elapsed time:  311.26800894737244 s
# 17年8月 冷水 {'設備名': ['17年8月_冷水'], '平日昼・総': [290], '平日夜・総': [203], '平日昼・基準内': [285], '平日夜・基準内': [203], '平日昼基準率': [0.9827586206896551], '平日夜基準率': [1.0]}
# 17年8月 電力 elapsed time:  366.25740003585815 s
# 17年8月 電力 {'設備名': ['17年8月_電力'], '平日昼・総': [290], '平日夜・総': [203], '平日昼・基準内': [282], '平日夜・基準内': [198], '平日昼基準率': [0.9724137931034482], '平日夜基準率': [0.9753694581280788]}
# 17年9月
# 17年9月 蒸気 elapsed time:  239.53255558013916 s
# 17年9月 蒸気 {'設備名': ['17年9月_蒸気'], '平日昼・総': [398], '平日夜・総': [278], '平日昼・基準内': [341], '平日夜・基準内': [248], '平日昼基準率': [0.8567839195979899], '平日夜基準率': [0.8920863309352518]}
# 17年9月 冷水 elapsed time:  301.73797249794006 s
# 17年9月 冷水 {'設備名': ['17年9月_冷水'], '平日昼・総': [398], '平日夜・総': [278], '平日昼・基準内': [387], '平日夜・基準内': [269], '平日昼基準率': [0.9723618090452262], '平日夜基準率': [0.9676258992805755]}
# 17年9月 電力 elapsed time:  357.08719849586487 s
# 17年9月 電力 {'設備名': ['17年9月_電力'], '平日昼・総': [398], '平日夜・総': [278], '平日昼・基準内': [393], '平日夜・基準内': [271], '平日昼基準率': [0.9874371859296482], '平日夜基準率': [0.9748201438848921]}
# 17年10月
# 17年10月 蒸気 elapsed time:  244.46041584014893 s
# 17年10月 蒸気 {'設備名': ['17年10月_蒸気'], '平日昼・総': [350], '平日夜・総': [267], '平日昼・基準内': [295], '平日夜・基準内': [238], '平日昼基準率': [0.8428571428571429], '平日夜基準率': [0.8913857677902621]}
# 17年10月 冷水 elapsed time:  295.43496680259705 s
# 17年10月 冷水 {'設備名': ['17年10月_冷水'], '平日昼・総': [350], '平日夜・総': [267], '平日昼・基準内': [346], '平日夜・基準内': [267], '平日昼基準率': [0.9885714285714285], '平日夜基準率': [1.0]}
# 17年10月 電力 elapsed time:  371.08477210998535 s
# 17年10月 電力 {'設備名': ['17年10月_電力'], '平日昼・総': [350], '平日夜・総': [267], '平日昼・基準内': [341], '平日夜・基準内': [264], '平日昼基準率': [0.9742857142857143], '平日夜基準率': [0.9887640449438202]}
# 17年11月
# 17年11月 蒸気 elapsed time:  236.13937997817993 s
# 17年11月 蒸気 {'設備名': ['17年11月_蒸気'], '平日昼・総': [376], '平日夜・総': [272], '平日昼・基準内': [334], '平日夜・基準内': [257], '平日昼基準率': [0.8882978723404256], '平日夜基準率': [0.9448529411764706]}
# 17年11月 冷水 elapsed time:  292.7554953098297 s
# 17年11月 冷水 {'設備名': ['17年11月_冷水'], '平日昼・総': [376], '平日夜・総': [272], '平日昼・基準内': [363], '平日夜・基準内': [264], '平日昼基準率': [0.9654255319148937], '平日夜基準率': [0.9705882352941176]}
# 17年11月 電力 elapsed time:  355.42132902145386 s
# 17年11月 電力 {'設備名': ['17年11月_電力'], '平日昼・総': [373], '平日夜・総': [271], '平日昼・基準内': [372], '平日夜・基準内': [266], '平日昼基準率': [0.9973190348525469], '平日夜基準率': [0.981549815498155]}
# 17年12月
# 17年12月 蒸気 elapsed time:  233.8487708568573 s
# 17年12月 蒸気 {'設備名': ['17年12月_蒸気'], '平日昼・総': [374], '平日夜・総': [270], '平日昼・基準内': [343], '平日夜・基準内': [260], '平日昼基準率': [0.9171122994652406], '平日夜基準率': [0.9629629629629629]}
# 17年12月 冷水 elapsed time:  281.6631908416748 s
# 17年12月 冷水 {'設備名': ['17年12月_冷水'], '平日昼・総': [374], '平日夜・総': [270], '平日昼・基準内': [361], '平日夜・基準内': [268], '平日昼基準率': [0.9652406417112299], '平日夜基準率': [0.9925925925925926]}
# 17年12月 電力 elapsed time:  362.1820967197418 s
# 17年12月 電力 {'設備名': ['17年12月_電力'], '平日昼・総': [374], '平日夜・総': [270], '平日昼・基準内': [372], '平日夜・基準内': [264], '平日昼基準率': [0.9946524064171123], '平日夜基準率': [0.9777777777777777]}
# 18年1月
# 18年1月 蒸気 elapsed time:  234.27806067466736 s
# 18年1月 蒸気 {'設備名': ['18年1月_蒸気'], '平日昼・総': [351], '平日夜・総': [242], '平日昼・基準内': [297], '平日夜・基準内': [205], '平日昼基準率': [0.8461538461538461], '平日夜基準率': [0.8471074380165289]}
# 18年1月 冷水 elapsed time:  281.4942035675049 s
# 18年1月 冷水 {'設備名': ['18年1月_冷水'], '平日昼・総': [351], '平日夜・総': [242], '平日昼・基準内': [312], '平日夜・基準内': [209], '平日昼基準率': [0.8888888888888888], '平日夜基準率': [0.8636363636363636]}
# 18年1月 電力 elapsed time:  356.6312391757965 s
# 18年1月 電力 {'設備名': ['18年1月_電力'], '平日昼・総': [351], '平日夜・総': [242], '平日昼・基準内': [324], '平日夜・基準内': [216], '平日昼基準率': [0.9230769230769231], '平日夜基準率': [0.8925619834710744]}
# 18年2月
# 18年2月 蒸気 elapsed time:  241.73329615592957 s
# 18年2月 蒸気 {'設備名': ['18年2月_蒸気'], '平日昼・総': [330], '平日夜・総': [232], '平日昼・基準内': [295], '平日夜・基準内': [211], '平日昼基準率': [0.8939393939393939], '平日夜基準率': [0.9094827586206896]}
# 18年2月 冷水 elapsed time:  283.4155240058899 s
# 18年2月 冷水 {'設備名': ['18年2月_冷水'], '平日昼・総': [330], '平日夜・総': [232], '平日昼・基準内': [314], '平日夜・基準内': [219], '平日昼基準率': [0.9515151515151515], '平日夜基準率': [0.9439655172413793]}
# 18年2月 電力 elapsed time:  365.7168827056885 s
# 18年2月 電力 {'設備名': ['18年2月_電力'], '平日昼・総': [330], '平日夜・総': [232], '平日昼・基準内': [324], '平日夜・基準内': [227], '平日昼基準率': [0.9818181818181818], '平日夜基準率': [0.978448275862069]}

# %% [markdown]
# ### Error check

# %%
for m, f in zip(month, month_file):
    print(m)

    df = read_df(f, '電力')
    x, y = mask_out(df.iloc[:-1, :-1], df.iloc[1:, -1], m)
    
    for i, v in y.iteritems():
        
        if v > 10000:
            print(m, i, v)
# Out:
# 16年11月
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-7dd532fb8942> in <module>()
#       2     print(m)
#       3
# ----> 4     df = read_df(f, '電力')
#       5     x, y = mask_out(df.iloc[:-1, :-1], df.iloc[1:, -1], m)
#       6
#
# TypeError: read_df() missing 1 required positional argument: 'sheet_name'

# %%
import os

for subdir, dirs, files in os.walk(base_out_dir):
    for file in files:
        
        if 'without' in file:
            print(os.path.join(subdir, file))
            os.remove(os.path.join(subdir, file))

# %%
res_dir = 'D:\\Toppan\\2017-11-20 全データ\\解析結果(総量)\\年間モデル\\追加学習なし\\ExtraTrees_year'

months = ['17年11月', '17年12月', '18年1月', '18年2月']

holidays = [[3, 23], [23, 29, 30, 31], [1, 2, 3, 4, 8], [10, 11, 12, 25]]

total_acc = []
for m, h in zip(months, holidays):
    for e in energies:
        
        result = pd.read_csv(os.path.join(res_dir, m, e + '.csv'), 
                             index_col=0, parse_dates=True,
                             encoding='shift-jis', engine='python')
        
        result = result.drop([x for x in result.index if x.day in h])
        
        
        # accuracy
        output = {'設備名': [], 
                  '平日昼・総': [], '平日夜・総': [], 
                  '平日昼・基準内': [], '平日夜・基準内': [], 
                  '平日昼基準率': [], '平日夜基準率': []}

        output = get_output(result, output, e, m)

        print(m, e, output)

        # save accuracy
        accs = pd.DataFrame(output)
        total_acc.append(accs)
    
total_acc = pd.concat(total_acc)

total_acc.to_csv(os.path.join(res_dir, '1711-1802_acc.csv'), 
                 index=False, 
                 encoding='shift-jis')
total_acc

# %%
744-96-24-20
# Out:
# 604

# %% [markdown]
# ### Collect VOC 2017/11 ~ 2018/2

# %%
root_dir = 'D:\\download\\201711_201802'
out_dir = 'D:\\download'

dirs = os.listdir(root_dir)

index = pd.date_range('2017/11/1 8:00', periods=length, freq='H')
df_voc = pd.DataFrame(index=index, columns=['VOC再利用生成量', 'VOC燃料生成量'])

for d in dirs:
    
    file_dir = os.path.join(root_dir, d)
    files = os.listdir(file_dir)
    for f in files:
        #if len(f) != 8: continue
            
        f_path = os.path.join(root_dir, d, f)
        ffs = os.listdir(f_path)
        for ff in ffs:
            
            if 'VOC' not in ff: 
                continue
                
            ff_path = os.path.join(root_dir, d, f, ff)
            
            df = pd.read_csv(ff_path, 
                        encoding='shift-jis', 
                        index_col=0, 
                        parse_dates=True, 
                        engine='python')
            
            if 'VOC再利用生成量' in df:
                df_voc.loc[df.index, 'VOC再利用生成量'] = df['VOC再利用生成量'].iloc[0]
            if 'VOC燃料生成量' in df:
                df_voc.loc[df.index, 'VOC燃料生成量'] = df['VOC燃料生成量'].iloc[0]

df_voc.to_csv(os.path.join(out_dir, 'voc.csv'), 
                          encoding='shift-jis')

print('over')
# Out:
# over

# %%
df=pd.read_excel('D:\\download\\VOC全休日雷モード.xlsx', 
                 sheet_name='Sheet1', 
                 encoding='shift-jis', index_col=0)

df.drop(index=['時刻'], inplace=True)
df.to_csv('D:\\download\\VOC全休日雷モード_v2.csv',
                                          encoding='shift-jis')
