# %%
import pandas as pd
import os
import numpy as np
from datetime import timedelta
import time
import glob

from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

in_dir = 'D:\\Toppan\\2017-11-20 全データ\\処理済(総量)\\vectorized_keikaku_shibata'
files = [f for f in os.listdir(in_dir)]

voc_dir_base = 'D:\\Toppan\\2017-11-20 全データ\\データ\\'


base_out_dir = 'D:\\Toppan\\2017-11-20 全データ\\解析結果(総量)\\年間モデル\\追加学習なし'

# train and test data
energies = ['蒸気', '冷水', '電力']
month = [ '16年11月', '16年12月', '17年1月', '17年2月', '17年3月', '17年4月',
         '17年5月', '17年6月', '17年7月', '17年8月', '17年9月', '17年10月']

month_file = [  '201611010800.xlsx', '201612010800.xlsx', 
                '201701010800.xlsx', '201702010800.xlsx', '201703010800.xlsx',
                '201704010800.xlsx', '201705010800.xlsx', '201706010800.xlsx',
                '201707010800.xlsx', '201708010800.xlsx', '201709010800.xlsx',
                '201710010800.xlsx']

# %%
def read_df(file, month, sheet_name):
    
    # data
    df = pd.read_excel(os.path.join(in_dir, file), sheet_name=sheet_name)
    
    # April special case
    if month == '17年4月':
        df = df.iloc[:358]
    
    # voc
    voc_dir = os.path.join(voc_dir_base, month, 'VOC再利用追加')
    voc_f = glob.glob(voc_dir + '/*.csv')[0]
    df_voc = pd.read_csv(voc_f, index_col=0, 
                         encoding='shift-jis', 
                         engine='python', 
                         parse_dates=True).fillna(0)
    
    df.columns = [
        '総稼動時間-3', '計画投入数(Ｒ)-3', '外気温度-3', '外気湿度-3', '計画色数-3', '段取-3', 
        '計画停止-3', '計画開始完了数-3', sheet_name + '-3',
        
        '総稼動時間-2', '計画投入数(Ｒ)-2', '外気温度-2', '外気湿度-2', '計画色数-2', '段取-2', 
        '計画停止-2', '計画開始完了数-2', sheet_name + '-2',
        
        '総稼動時間-1', '計画投入数(Ｒ)-1', '外気温度-1', '外気湿度-1', '計画色数-1', '段取-1', 
        '計画停止-1', '計画開始完了数-1', sheet_name + '-1',
        
        'target']
    
    # add voc to data
    df['VOC燃料生成量-3'] = pd.Series(data=df_voc['VOC燃料生成量'].iloc[:-2].values, index=df.index)
    df['VOC燃料生成量-2'] = pd.Series(data=df_voc['VOC燃料生成量'].iloc[1:-1].values, index=df.index)
    df['VOC燃料生成量-1'] = pd.Series(data=df_voc['VOC燃料生成量'].iloc[2:].values, index=df.index)
    
    df['VOC再利用生成量-3'] = pd.Series(data=df_voc['VOC再利用生成量'].iloc[:-2].values, index=df.index)
    df['VOC再利用生成量-2'] = pd.Series(data=df_voc['VOC再利用生成量'].iloc[1:-1].values, index=df.index)
    df['VOC再利用生成量-1'] = pd.Series(data=df_voc['VOC再利用生成量'].iloc[2:].values, index=df.index)
    
    return df

# %%
holiday_path = 'D:\\Toppan\\2017-11-20 全データ\\データ\\切り離し全休日\\全休日.xlsx'

def mask_out(X, y, month):
    
    try:
        df_filter = pd.read_excel(holiday_path, sheet_name=month, index_col=0).iloc[2:]
    except Exception as e:
        print(e, month)
        return X, y
    
    seisan = True if '生産\n有無' in df_filter else False
    
    def isBusy(idx):
        row = df_filter.loc[idx]
        if row.loc['切離\n有無'] == '切離' or row.loc['全休\n判定'] == '全休' \
            or row.loc['異常判定'] == '※異常稼動' or (seisan and row.loc['生産\n有無'] == '無'):
            return False
        else:
            return True
        
    x_busy_idx = []
    y_busy_idx = []
    for x_idx, y_idx in zip (X.index, y.index):
        if isBusy(x_idx) and isBusy(y_idx):
            x_busy_idx.append(x_idx)
            y_busy_idx.append(y_idx)
    
    return X.loc[x_busy_idx], y.loc[y_busy_idx]

# %%
def get_importance_figure(model, name, features):
    
    indices = np.argsort(model.feature_importances_)[::-1]
    
    # save csv
    s = pd.Series(data=model.feature_importances_[indices], 
              index=features[indices])
    s.to_csv(os.path.join(out_dir, name + '_寄与度.csv'), encoding='shift-jis')

# %%
def split_day_night(acc_abs):
    acc_abs_days, acc_abs_nights = [], []
    for i, acc in acc_abs.iteritems():
        if 7 < i.hour < 22:
            acc_abs_days.append(acc)
        else:
            acc_abs_nights.append(acc)

    return acc_abs_days, acc_abs_nights

def get_output(res, output, sname, month):
    res = res[res['target'] != 0]
    
    if len(res) == 0:
        return None
    
    y_pred, y_true = res['preds'], res['target']
    '''calculate abs accuracy'''
    acc_abs = abs(y_pred - y_true) / y_true
    '''aplit days and nights'''
    acc_abs_days, acc_abs_nights = split_day_night(acc_abs)
    len_days, len_nights = len(acc_abs_days), len(acc_abs_nights)

    sname2acc = {'蒸気': [0.2, 0.15], '電力': [0.09, 0.15], '冷水': [0.15, 0.1]}

    '''acc stats'''
    len_acc_days = len(list(filter(lambda x: x <= sname2acc[sname][0], acc_abs_days)))
    len_acc_nights = len(list(filter(lambda x: x <= sname2acc[sname][0], acc_abs_nights)))
    acc_stats_days = len_acc_days / len_days
    acc_stats_nights = len_acc_nights / len_nights

    output['設備名'].append(month + '_' + sname)
    output['平日昼・総'].append(len_days)
    output['平日夜・総'].append(len_nights)
    output['平日昼・基準内'].append(len_acc_days)
    output['平日夜・基準内'].append(len_acc_nights)
    output['平日昼基準率'].append(acc_stats_days)
    output['平日夜基準率'].append(acc_stats_nights)

    return output

# %% [markdown]
# ### 月データを学習

# %%
def get_model(mtype='et'):
    if mtype == 'rf':
        model = RandomForestRegressor(n_estimators=700, 
                                          n_jobs=-1, 
                                          max_depth=11, 
                                          max_features='auto', 
                                          criterion='mae', 
                                          random_state=700, 
                                          warm_start=True)
    else:
        model = ExtraTreesRegressor(n_estimators=700, 
                                          n_jobs=-1, 
                                          max_depth=11, 
                                          max_features='auto', 
                                          criterion='mae', 
                                          random_state=700, 
                                          warm_start=True)
    return model

# %%
total_acc = []

for i, (m, f) in enumerate(zip(month, month_file)):
    print(m)
    
    # the last month
    if m == '17年10月':
        continue
    
    # create output dir
    out_dir = os.path.join(base_out_dir, m)
    if not os.path.exists(out_dir):
        os.makedirs(out_dir)
    
    # set train, trans, test files
    train_month, train_month_file = m, f
    test_month, test_month_file = month[i + 1], month_file[i + 1]
    trans_month, trans_month_file = [x for x in month if x not in [train_month, test_month]], \
                    [x for x in month_file if x not in [train_month_file, test_month_file]]
    
    print('train: ', train_month, train_month_file)
    print('test: ', test_month, test_month_file)
    print('trans: ', trans_month, trans_month_file)
    
    # base train model
    for energy in energies:

        df_train = read_df(train_month_file, train_month, energy)
                
        x_train, y_train = mask_out(df_train.drop(columns=['target']).iloc[:-1], 
                            df_train['target'].iloc[1:], train_month)
        
        # base model
        base_model = get_model()
        base_model.fit(x_train, y_train)

        # database preparation
        x_trans_all, y_trans_all = [], []
        for trans_m, trans_f in zip(trans_month, trans_month_file):
            df_trans = read_df(trans_f, trans_m, energy)
            x_trans, y_trans = mask_out(df_trans.drop(columns=['target']).iloc[:-1], 
                                        df_trans['target'].iloc[1:], trans_m)

            x_trans_all.append(x_trans)
            y_trans_all.append(y_trans)

        x_trans_all, y_trans_all = pd.concat(x_trans_all), pd.concat(y_trans_all)
        
        # pick up transfer data from data base
        start = time.time()
        x_picked, y_picked = [], []
        for idx, row in x_trans_all.iterrows():
            pred = base_model.predict(row.values.reshape(1, -1))[0]
            true = y_trans_all.loc[idx + timedelta(hours=1)]
            
            if true != 0 and np.abs(pred - true) / true <= 0.025:
                x_picked.append(row)
                y_picked.append(true)

        elapsed_time = time.time() - start
        print(train_month, energy, 'transfer elapsed time: ', elapsed_time, 's')
        print('    number of data picked: ', len(x_picked))
      
        # concat train and picked data
        x_train_trans = np.vstack((x_train, x_picked))
        y_train_trans = np.append(y_train, y_picked)
        # dump
        tt_data = np.hstack((x_train_trans, y_train_trans.reshape(-1, 1)))
        np.savetxt(os.path.join(out_dir, energy + '_学習_転移.csv'), 
                   tt_data, delimiter=',')
        
        print(len(x_train_trans))
        
        # test model
        model = get_model()
                                     
        # learn 1 hour later target
        start = time.time()
        model.fit(x_train_trans, y_train_trans)
        elapsed_time = time.time() - start

        print(train_month, energy, 'train elapsed time: ', elapsed_time, 's')

        # feature importance
        get_importance_figure(model, energy, x_train.columns)
                                     
        # test file
        df_test = read_df(test_month_file, test_month, energy)
        x_test, y_test = mask_out(df_test.drop(columns=['target']).iloc[:-1], 
                                  df_test['target'].iloc[1:], test_month)
                                     
        # test with online learning
        preds = []
        for idx, row in x_test.iterrows():

            # predict
            preds.append(model.predict(row.values.reshape(1, -1))[0])

            # online learning
            '''
            model.n_estimators += 50

            X_learn = X_learn.append(row)
            Y_learn = Y_learn.append(pd.Series(data=Y_test.loc[idx + timedelta(hours=1)], 
                      index=[idx + timedelta(hours=1)]))

            model.fit(X_learn, Y_learn)
            '''

        # save preds and test
        preds = pd.Series(data=preds, index=y_test.index, name='preds')
        result = pd.concat([preds, y_test], axis=1)
        result.to_csv(os.path.join(out_dir, energy + '.csv'), encoding='shift-jis')

        # accuracy
        output = {'設備名': [], 
                  '平日昼・総': [], '平日夜・総': [], 
                  '平日昼・基準内': [], '平日夜・基準内': [], 
                  '平日昼基準率': [], '平日夜基準率': []}
        
        output = get_output(result, output, energy, test_month)
        
        print(test_month, energy, output)

        # save accuracy
        accs = pd.DataFrame(output)
        accs.to_csv(os.path.join(out_dir, energy + '_acc.csv'), index=False, encoding='shift-jis')
        
        total_acc.append(accs)
        
total_acc = pd.concat(total_acc)
total_acc.to_csv(os.path.join(base_out_dir, 'total_acc.csv'), index=False, encoding='shift-jis')
# Out:
# 16年11月
# train:  16年11月 201611010800.xlsx
# test:  16年12月 201612010800.xlsx
# trans:  ['17年1月', '17年2月', '17年3月', '17年4月', '17年5月', '17年6月', '17年7月', '17年8月', '17年9月', '17年10月'] ['201701010800.xlsx', '201702010800.xlsx', '201703010800.xlsx', '201704010800.xlsx', '201705010800.xlsx', '201706010800.xlsx', '201707010800.xlsx', '201708010800.xlsx', '201709010800.xlsx', '201710010800.xlsx']
# 16年11月 蒸気 transfer elapsed time:  930.6326749324799 s
#     number of data picked:  713
# 1316
# 16年11月 蒸気 train elapsed time:  10.251039981842041 s
# 16年12月 蒸気 {'設備名': ['16年12月_蒸気'], '平日昼・総': [152], '平日夜・総': [243], '平日昼・基準内': [139], '平日夜・基準内': [225], '平日昼基準率': [0.9144736842105263], '平日夜基準率': [0.9259259259259259]}
# 16年11月 冷水 transfer elapsed time:  923.7733235359192 s
#     number of data picked:  674
# 1277
# 16年11月 冷水 train elapsed time:  10.13408374786377 s
# 16年12月 冷水 {'設備名': ['16年12月_冷水'], '平日昼・総': [149], '平日夜・総': [243], '平日昼・基準内': [139], '平日夜・基準内': [240], '平日昼基準率': [0.9328859060402684], '平日夜基準率': [0.9876543209876543]}
# 16年11月 電力 transfer elapsed time:  922.6296532154083 s
#     number of data picked:  2692
# 3295
# 16年11月 電力 train elapsed time:  60.68183255195618 s
# 16年12月 電力 {'設備名': ['16年12月_電力'], '平日昼・総': [151], '平日夜・総': [243], '平日昼・基準内': [144], '平日夜・基準内': [237], '平日昼基準率': [0.9536423841059603], '平日夜基準率': [0.9753086419753086]}
# 16年12月
# train:  16年12月 201612010800.xlsx
# test:  17年1月 201701010800.xlsx
# trans:  ['16年11月', '17年2月', '17年3月', '17年4月', '17年5月', '17年6月', '17年7月', '17年8月', '17年9月', '17年10月'] ['201611010800.xlsx', '201702010800.xlsx', '201703010800.xlsx', '201704010800.xlsx', '201705010800.xlsx', '201706010800.xlsx', '201707010800.xlsx', '201708010800.xlsx', '201709010800.xlsx', '201710010800.xlsx']
# 16年12月 蒸気 transfer elapsed time:  938.7099335193634 s
#     number of data picked:  665
# 1060
# 16年12月 蒸気 train elapsed time:  7.660891532897949 s
# 17年1月 蒸気 {'設備名': ['17年1月_蒸気'], '平日昼・総': [93], '平日夜・総': [222], '平日昼・基準内': [85], '平日夜・基準内': [205], '平日昼基準率': [0.9139784946236559], '平日夜基準率': [0.9234234234234234]}
# 16年12月 冷水 transfer elapsed time:  979.7165176868439 s
#     number of data picked:  954
# 1349
# 16年12月 冷水 train elapsed time:  10.754390001296997 s
# 17年1月 冷水 {'設備名': ['17年1月_冷水'], '平日昼・総': [93], '平日夜・総': [222], '平日昼・基準内': [89], '平日夜・基準内': [213], '平日昼基準率': [0.956989247311828], '平日夜基準率': [0.9594594594594594]}
# 16年12月 電力 transfer elapsed time:  979.0339872837067 s
#     number of data picked:  2286
# 2681
# 16年12月 電力 train elapsed time:  42.218688011169434 s
# 17年1月 電力 {'設備名': ['17年1月_電力'], '平日昼・総': [93], '平日夜・総': [222], '平日昼・基準内': [90], '平日夜・基準内': [214], '平日昼基準率': [0.967741935483871], '平日夜基準率': [0.963963963963964]}
# 17年1月
# train:  17年1月 201701010800.xlsx
# test:  17年2月 201702010800.xlsx
# trans:  ['16年11月', '16年12月', '17年3月', '17年4月', '17年5月', '17年6月', '17年7月', '17年8月', '17年9月', '17年10月'] ['201611010800.xlsx', '201612010800.xlsx', '201703010800.xlsx', '201704010800.xlsx', '201705010800.xlsx', '201706010800.xlsx', '201707010800.xlsx', '201708010800.xlsx', '201709010800.xlsx', '201710010800.xlsx']
# 17年1月 蒸気 transfer elapsed time:  950.1158559322357 s
#     number of data picked:  407
# 722
# 17年1月 蒸気 train elapsed time:  4.779618501663208 s
# 17年2月 蒸気 {'設備名': ['17年2月_蒸気'], '平日昼・総': [343], '平日夜・総': [235], '平日昼・基準内': [302], '平日夜・基準内': [215], '平日昼基準率': [0.880466472303207], '平日夜基準率': [0.9148936170212766]}
# 17年1月 冷水 transfer elapsed time:  947.6370801925659 s
#     number of data picked:  955
# 1270
# 17年1月 冷水 train elapsed time:  10.545035362243652 s
# 17年2月 冷水 {'設備名': ['17年2月_冷水'], '平日昼・総': [343], '平日夜・総': [235], '平日昼・基準内': [327], '平日夜・基準内': [225], '平日昼基準率': [0.9533527696793003], '平日夜基準率': [0.9574468085106383]}
# 17年1月 電力 transfer elapsed time:  949.517637014389 s
#     number of data picked:  2704
# 3019
# 17年1月 電力 train elapsed time:  47.65927743911743 s
# 17年2月 電力 {'設備名': ['17年2月_電力'], '平日昼・総': [343], '平日夜・総': [235], '平日昼・基準内': [333], '平日夜・基準内': [232], '平日昼基準率': [0.9708454810495627], '平日夜基準率': [0.9872340425531915]}
# 17年2月
# train:  17年2月 201702010800.xlsx
# test:  17年3月 201703010800.xlsx
# trans:  ['16年11月', '16年12月', '17年1月', '17年4月', '17年5月', '17年6月', '17年7月', '17年8月', '17年9月', '17年10月'] ['201611010800.xlsx', '201612010800.xlsx', '201701010800.xlsx', '201704010800.xlsx', '201705010800.xlsx', '201706010800.xlsx', '201707010800.xlsx', '201708010800.xlsx', '201709010800.xlsx', '201710010800.xlsx']
# 17年2月 蒸気 transfer elapsed time:  904.5547671318054 s
#     number of data picked:  364
# 942
# 17年2月 蒸気 train elapsed time:  6.840038776397705 s
# 17年3月 蒸気 {'設備名': ['17年3月_蒸気'], '平日昼・総': [370], '平日夜・総': [286], '平日昼・基準内': [332], '平日夜・基準内': [260], '平日昼基準率': [0.8972972972972973], '平日夜基準率': [0.9090909090909091]}
# 17年2月 冷水 transfer elapsed time:  899.8670091629028 s
#     number of data picked:  649
# 1227
# 17年2月 冷水 train elapsed time:  10.631989479064941 s
# 17年3月 冷水 {'設備名': ['17年3月_冷水'], '平日昼・総': [370], '平日夜・総': [286], '平日昼・基準内': [361], '平日夜・基準内': [279], '平日昼基準率': [0.9756756756756757], '平日夜基準率': [0.9755244755244755]}
# 17年2月 電力 transfer elapsed time:  906.144651889801 s
#     number of data picked:  2510
# 3088
# 17年2月 電力 train elapsed time:  55.15695095062256 s
# 17年3月 電力 {'設備名': ['17年3月_電力'], '平日昼・総': [370], '平日夜・総': [286], '平日昼・基準内': [359], '平日夜・基準内': [276], '平日昼基準率': [0.9702702702702702], '平日夜基準率': [0.965034965034965]}
# 17年3月
# train:  17年3月 201703010800.xlsx
# test:  17年4月 201704010800.xlsx
# trans:  ['16年11月', '16年12月', '17年1月', '17年2月', '17年5月', '17年6月', '17年7月', '17年8月', '17年9月', '17年10月'] ['201611010800.xlsx', '201612010800.xlsx', '201701010800.xlsx', '201702010800.xlsx', '201705010800.xlsx', '201706010800.xlsx', '201707010800.xlsx', '201708010800.xlsx', '201709010800.xlsx', '201710010800.xlsx']
# 17年3月 蒸気 transfer elapsed time:  937.847418308258 s
#     number of data picked:  596
# 1252
# 17年3月 蒸気 train elapsed time:  9.144238948822021 s
# 17年4月 蒸気 {'設備名': ['17年4月_蒸気'], '平日昼・総': [198], '平日夜・総': [146], '平日昼・基準内': [157], '平日夜・基準内': [129], '平日昼基準率': [0.7929292929292929], '平日夜基準率': [0.8835616438356164]}
# 17年3月 冷水 transfer elapsed time:  933.141117811203 s
#     number of data picked:  552
# 1208
# 17年3月 冷水 train elapsed time:  10.694833040237427 s
# 17年4月 冷水 {'設備名': ['17年4月_冷水'], '平日昼・総': [198], '平日夜・総': [146], '平日昼・基準内': [179], '平日夜・基準内': [127], '平日昼基準率': [0.9040404040404041], '平日夜基準率': [0.8698630136986302]}
# 17年3月 電力 transfer elapsed time:  938.2325050830841 s
#     number of data picked:  2702
# 3358
# 17年3月 電力 train elapsed time:  63.061819314956665 s
# 17年4月 電力 {'設備名': ['17年4月_電力'], '平日昼・総': [198], '平日夜・総': [146], '平日昼・基準内': [196], '平日夜・基準内': [144], '平日昼基準率': [0.98989898989899], '平日夜基準率': [0.9863013698630136]}
# 17年4月
# train:  17年4月 201704010800.xlsx
# test:  17年5月 201705010800.xlsx
# trans:  ['16年11月', '16年12月', '17年1月', '17年2月', '17年3月', '17年6月', '17年7月', '17年8月', '17年9月', '17年10月'] ['201611010800.xlsx', '201612010800.xlsx', '201701010800.xlsx', '201702010800.xlsx', '201703010800.xlsx', '201706010800.xlsx', '201707010800.xlsx', '201708010800.xlsx', '201709010800.xlsx', '201710010800.xlsx']
# 17年4月 蒸気 transfer elapsed time:  945.2054719924927 s
#     number of data picked:  686
# 1030
# 17年4月 蒸気 train elapsed time:  9.232386589050293 s
# 17年5月 蒸気 {'設備名': ['17年5月_蒸気'], '平日昼・総': [364], '平日夜・総': [255], '平日昼・基準内': [226], '平日夜・基準内': [196], '平日昼基準率': [0.6208791208791209], '平日夜基準率': [0.7686274509803922]}
# 17年4月 冷水 transfer elapsed time:  944.6950740814209 s
#     number of data picked:  917
# 1261
# 17年4月 冷水 train elapsed time:  11.356057167053223 s
# 17年5月 冷水 {'設備名': ['17年5月_冷水'], '平日昼・総': [360], '平日夜・総': [255], '平日昼・基準内': [251], '平日夜・基準内': [218], '平日昼基準率': [0.6972222222222222], '平日夜基準率': [0.8549019607843137]}
# 17年4月 電力 transfer elapsed time:  947.312166929245 s
#     number of data picked:  2527
# 2871
# 17年4月 電力 train elapsed time:  46.514182806015015 s
# 17年5月 電力 {'設備名': ['17年5月_電力'], '平日昼・総': [364], '平日夜・総': [255], '平日昼・基準内': [350], '平日夜・基準内': [246], '平日昼基準率': [0.9615384615384616], '平日夜基準率': [0.9647058823529412]}
# 17年5月
# train:  17年5月 201705010800.xlsx
# test:  17年6月 201706010800.xlsx
# trans:  ['16年11月', '16年12月', '17年1月', '17年2月', '17年3月', '17年4月', '17年7月', '17年8月', '17年9月', '17年10月'] ['201611010800.xlsx', '201612010800.xlsx', '201701010800.xlsx', '201702010800.xlsx', '201703010800.xlsx', '201704010800.xlsx', '201707010800.xlsx', '201708010800.xlsx', '201709010800.xlsx', '201710010800.xlsx']
# 17年5月 蒸気 transfer elapsed time:  887.9643740653992 s
#     number of data picked:  572
# 1191
# 17年5月 蒸気 train elapsed time:  9.322456359863281 s
# 17年6月 蒸気 {'設備名': ['17年6月_蒸気'], '平日昼・総': [384], '平日夜・総': [273], '平日昼・基準内': [330], '平日夜・基準内': [247], '平日昼基準率': [0.859375], '平日夜基準率': [0.9047619047619048]}
# 17年5月 冷水 transfer elapsed time:  892.8680698871613 s
#     number of data picked:  1218
# 1837
# 17年5月 冷水 train elapsed time:  16.709941625595093 s
# 17年6月 冷水 {'設備名': ['17年6月_冷水'], '平日昼・総': [384], '平日夜・総': [273], '平日昼・基準内': [380], '平日夜・基準内': [263], '平日昼基準率': [0.9895833333333334], '平日夜基準率': [0.9633699633699634]}
# 17年5月 電力 transfer elapsed time:  893.3803842067719 s
#     number of data picked:  1056
# 1675
# 17年5月 電力 train elapsed time:  16.59664821624756 s
# 17年6月 電力 {'設備名': ['17年6月_電力'], '平日昼・総': [384], '平日夜・総': [273], '平日昼・基準内': [330], '平日夜・基準内': [229], '平日昼基準率': [0.859375], '平日夜基準率': [0.8388278388278388]}
# 17年6月
# train:  17年6月 201706010800.xlsx
# test:  17年7月 201707010800.xlsx
# trans:  ['16年11月', '16年12月', '17年1月', '17年2月', '17年3月', '17年4月', '17年5月', '17年8月', '17年9月', '17年10月'] ['201611010800.xlsx', '201612010800.xlsx', '201701010800.xlsx', '201702010800.xlsx', '201703010800.xlsx', '201704010800.xlsx', '201705010800.xlsx', '201708010800.xlsx', '201709010800.xlsx', '201710010800.xlsx']
# 17年6月 蒸気 transfer elapsed time:  887.6838481426239 s
#     number of data picked:  473
# 1130
# 17年6月 蒸気 train elapsed time:  8.529487133026123 s
# 17年7月 蒸気 {'設備名': ['17年7月_蒸気'], '平日昼・総': [376], '平日夜・総': [288], '平日昼・基準内': [288], '平日夜・基準内': [244], '平日昼基準率': [0.7659574468085106], '平日夜基準率': [0.8472222222222222]}
# 17年6月 冷水 transfer elapsed time:  861.8665788173676 s
#     number of data picked:  1388
# 2045
# 17年6月 冷水 train elapsed time:  20.78757929801941 s
# 17年7月 冷水 {'設備名': ['17年7月_冷水'], '平日昼・総': [376], '平日夜・総': [288], '平日昼・基準内': [289], '平日夜・基準内': [269], '平日昼基準率': [0.7686170212765957], '平日夜基準率': [0.9340277777777778]}
# 17年6月 電力 transfer elapsed time:  659.430223941803 s
#     number of data picked:  2555
# 3212
# 17年6月 電力 train elapsed time:  50.367522954940796 s
# 17年7月 電力 {'設備名': ['17年7月_電力'], '平日昼・総': [376], '平日夜・総': [288], '平日昼・基準内': [375], '平日夜・基準内': [280], '平日昼基準率': [0.9973404255319149], '平日夜基準率': [0.9722222222222222]}
# 17年7月
# train:  17年7月 201707010800.xlsx
# test:  17年8月 201708010800.xlsx
# trans:  ['16年11月', '16年12月', '17年1月', '17年2月', '17年3月', '17年4月', '17年5月', '17年6月', '17年9月', '17年10月'] ['201611010800.xlsx', '201612010800.xlsx', '201701010800.xlsx', '201702010800.xlsx', '201703010800.xlsx', '201704010800.xlsx', '201705010800.xlsx', '201706010800.xlsx', '201709010800.xlsx', '201710010800.xlsx']
# 17年7月 蒸気 transfer elapsed time:  679.7786498069763 s
#     number of data picked:  310
# 974
# 17年7月 蒸気 train elapsed time:  7.198876142501831 s
# 17年8月 蒸気 {'設備名': ['17年8月_蒸気'], '平日昼・総': [290], '平日夜・総': [203], '平日昼・基準内': [247], '平日夜・基準内': [174], '平日昼基準率': [0.8517241379310345], '平日夜基準率': [0.8571428571428571]}
# 17年7月 冷水 transfer elapsed time:  680.0072200298309 s
#     number of data picked:  312
# 976
# 17年7月 冷水 train elapsed time:  7.327016830444336 s
# 17年8月 冷水 {'設備名': ['17年8月_冷水'], '平日昼・総': [290], '平日夜・総': [203], '平日昼・基準内': [284], '平日夜・基準内': [193], '平日昼基準率': [0.9793103448275862], '平日夜基準率': [0.9507389162561576]}
# 17年7月 電力 transfer elapsed time:  571.3736820220947 s
#     number of data picked:  2856
# 3520
# 17年7月 電力 train elapsed time:  67.08129715919495 s
# 17年8月 電力 {'設備名': ['17年8月_電力'], '平日昼・総': [290], '平日夜・総': [203], '平日昼・基準内': [284], '平日夜・基準内': [198], '平日昼基準率': [0.9793103448275862], '平日夜基準率': [0.9753694581280788]}
# 17年8月
# train:  17年8月 201708010800.xlsx
# test:  17年9月 201709010800.xlsx
# trans:  ['16年11月', '16年12月', '17年1月', '17年2月', '17年3月', '17年4月', '17年5月', '17年6月', '17年7月', '17年10月'] ['201611010800.xlsx', '201612010800.xlsx', '201701010800.xlsx', '201702010800.xlsx', '201703010800.xlsx', '201704010800.xlsx', '201705010800.xlsx', '201706010800.xlsx', '201707010800.xlsx', '201710010800.xlsx']
# 17年8月 蒸気 transfer elapsed time:  561.8969855308533 s
#     number of data picked:  427
# 920
# 17年8月 蒸気 train elapsed time:  7.231220960617065 s
# 17年9月 蒸気 {'設備名': ['17年9月_蒸気'], '平日昼・総': [398], '平日夜・総': [278], '平日昼・基準内': [326], '平日夜・基準内': [225], '平日昼基準率': [0.8190954773869347], '平日夜基準率': [0.8093525179856115]}
# 17年8月 冷水 transfer elapsed time:  562.0418620109558 s
#     number of data picked:  647
# 1140
# 17年8月 冷水 train elapsed time:  9.20245909690857 s
# 17年9月 冷水 {'設備名': ['17年9月_冷水'], '平日昼・総': [398], '平日夜・総': [278], '平日昼・基準内': [335], '平日夜・基準内': [198], '平日昼基準率': [0.8417085427135679], '平日夜基準率': [0.7122302158273381]}
# 17年8月 電力 transfer elapsed time:  561.6558337211609 s
#     number of data picked:  2443
# 2936
# 17年8月 電力 train elapsed time:  53.278608322143555 s
# 17年9月 電力 {'設備名': ['17年9月_電力'], '平日昼・総': [398], '平日夜・総': [278], '平日昼・基準内': [371], '平日夜・基準内': [263], '平日昼基準率': [0.9321608040201005], '平日夜基準率': [0.9460431654676259]}
# 17年9月
# train:  17年9月 201709010800.xlsx
# test:  17年10月 201710010800.xlsx
# trans:  ['16年11月', '16年12月', '17年1月', '17年2月', '17年3月', '17年4月', '17年5月', '17年6月', '17年7月', '17年8月'] ['201611010800.xlsx', '201612010800.xlsx', '201701010800.xlsx', '201702010800.xlsx', '201703010800.xlsx', '201704010800.xlsx', '201705010800.xlsx', '201706010800.xlsx', '201707010800.xlsx', '201708010800.xlsx']
# 17年9月 蒸気 transfer elapsed time:  549.3558769226074 s
#     number of data picked:  483
# 1159
# 17年9月 蒸気 train elapsed time:  10.135940313339233 s
# 17年10月 蒸気 {'設備名': ['17年10月_蒸気'], '平日昼・総': [350], '平日夜・総': [267], '平日昼・基準内': [291], '平日夜・基準内': [215], '平日昼基準率': [0.8314285714285714], '平日夜基準率': [0.8052434456928839]}
# 17年9月 冷水 transfer elapsed time:  549.5044600963593 s
#     number of data picked:  1340
# 2016
# 17年9月 冷水 train elapsed time:  21.345765352249146 s
# 17年10月 冷水 {'設備名': ['17年10月_冷水'], '平日昼・総': [350], '平日夜・総': [267], '平日昼・基準内': [341], '平日夜・基準内': [263], '平日昼基準率': [0.9742857142857143], '平日夜基準率': [0.9850187265917603]}
# 17年9月 電力 transfer elapsed time:  549.6900153160095 s
#     number of data picked:  2819
# 3495
# 17年9月 電力 train elapsed time:  71.60729622840881 s
# 17年10月 電力 {'設備名': ['17年10月_電力'], '平日昼・総': [350], '平日夜・総': [267], '平日昼・基準内': [339], '平日夜・基準内': [264], '平日昼基準率': [0.9685714285714285], '平日夜基準率': [0.9887640449438202]}
# 17年10月
